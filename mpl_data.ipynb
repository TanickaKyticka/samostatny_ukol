# %%
data = np.load("pacienti.npy")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#       2
#       3 # 1. Načtení dat
#       4 data = np.load("pacienti.npy")
#
# ModuleNotFoundError: No module named 'numpy'
